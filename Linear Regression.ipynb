# %%
from sklearn import linear_model
import numpy as np
X = np.array([2.3,4.5,6.7,8.8,9.2])
Y = np.array([3.2,4.3,5.1,6.5,7.6])

# %%
reg=linear_model.LinearRegression()

# %%
X=X.reshape(5,1)
Y=Y.reshape(5,1)

# %%
reg.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print("slope= ",reg.coef_)
print("intercept= ",reg.intercept_)
# Out:
# slope=  [[0.58103347]]
# intercept=  [1.67948914]

# %%
import pandas as pd

# %%
adv=pd.read_csv(r'C:\Users\sauhard\Downloads\datasets_9378_13223_Advertising.csv')
adv.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
adv=adv[['TV','radio','newspaper','sales']]

# %%
adv.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
X=adv[['TV']]
Y=adv[['sales']]

# %%
import matplotlib.pyplot as plt
plt.scatter(X,Y)
plt.show()

# %%
regr=linear_model.LinearRegression()
regr.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
m=print(regr.coef_)
# Out:
# [[0.04753664]]

# %%
c=print(regr.intercept_)
# Out:
# [7.03259355]

# %%
Yp=regr.predict(X)

# %%
plt.scatter(X,Y)
plt.plot(X,Yp,c='red')
plt.show()

# %%
regr.predict([[22.6],[13.5]])
# Out:
# array([[8.10692162],
#        [7.67433819]])

# %%
from sklearn import metrics

# %%
X=adv[['TV','radio']]
Y=adv[['sales']]
reg1=linear_model.LinearRegression()
reg1.fit(X,Y)
print("m:",reg1.coef_)
print("c:",reg1.intercept_)
Yp=reg1.predict(X)
print(metrics.mean_absolute_error(Y,Yp))
print(metrics.mean_squared_error(Y,Yp))
# Out:
# m: [[0.04575482 0.18799423]]
# c: [2.92109991]
# 1.2537471644234008
# 2.7845699003380924

# %%
adv.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
x0=1
x1=4
x2=6
x3=3

# %%
y=49

# %%
m0=.1
m1=.4
m2=.47
m3=.8

# %%
yp=m0*x0+m1*x1+m2*x2+m3*x3

# %%
yp
# Out:
# 6.92

# %%
(y-yp)**2
# Out:
# 1770.7263999999998

# %%
error_values = []
for i in range(50):

  yp = m0*x0 + m1*x1 + m2*x2+m3*x3

  dem0 = 2 * (y-yp) * (-x0)
  dem1 = 2 * (y-yp) * (-x1)
  dem2 = 2 * (y-yp) * (-x2)
  dem3 = 2 * (y-yp) * (-x3)

  m0 = m0 - 0.001 * dem0
  m1 = m1 - 0.001 * dem1
  m2 = m2 - 0.001 * dem2
  m3 = m3 - 0.001 * dem3

  error = (Y-Yp)**2
  error_values.append(error)
  print('Bias:', m0 ,'coef1:',m1, 'coef2:',m2,'coef3:',m3 , 'Error:',error)
# Out:
# Bias: 0.18416 coef1: 0.73664 coef2: 0.9749599999999999 coef3: 1.05248 Error:         sales
# 0    2.385589
# 1    3.784434
# 2    9.223477
# 3    0.779484
# 4    0.104916
# ..        ...
# 195  4.997404
# 196  2.395143
# 197  0.001021
# 198  2.914112
# 199  3.088957
#
# [200 rows x 1 columns]
# Bias: 0.25788416 coef1: 1.03153664 coef2: 1.41730496 coef3: 1.27365248 Error:         sales
# 0    2.385589
# 1    3.784434
# 2    9.223477
# 3    0.779484
# 4    0.104916
# ..        ...
# 195  4.997404
# 196  2.395143
# 197  0.001021
# 198  2.914112
# 199  3.088957
#
# [200 rows x 1 columns]
# Bias: 0.32246652416 coef1: 1.28986609664 coef2: 1.80479914496 coef3: 1.46739957248 Error:         sales
# 0    2.385589
# 1    3.784434
# 2    9.223477
# 3    0.779484
# 4    0.104916
# ..        ...
# 195  4.997404
# 196  2.395143
# 197  0.001021
# 198  2.914112
# 199  3.088957
#
# [200 rows x 1 columns]
# ...
